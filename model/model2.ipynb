# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/hsmad/Downloads/task_3.txt")
df.head()
# Out:
#    0      09:40:50  26.0466  10.0252  14.4485  8.4499  16.1151    13.43  \
# 0  1  09:40:50.002  22.3896  11.2917  15.5731  8.2512  15.2678  14.7828
# 1  2  09:40:50.004  16.6999  11.5905  15.6996  7.4461  14.1830  14.9755
# 2  3  09:40:50.006   9.5022  11.6445  14.6918  6.2064  12.5756  14.4724
# 3  4  09:40:50.008   2.1006  11.8186  12.9464  5.5676  10.6398  13.8879
# 4  5  09:40:50.010  -4.0280  11.6355  11.1315  6.4536   9.0430  13.3979
#
#     19.649  13.3862  ...  0.0.12  0.0.13  -188.00000000000003       8411.0  \
# 0  20.3893  14.9479  ...     0.0     0.0          -172.349903  8414.343387
# 1  20.5631  15.1158  ...     0.0     0.0          -155.794864  8418.160738
# 2  19.8746  14.2122  ...     0.0     0.0          -140.564873  8424.106395
# 3  18.5196  12.7470  ...     0.0     0.0          -128.889922  8433.834701
# 4  16.9767  11.0312  ...     0.0     0.0          -123.000000  8449.000000
#
#    427.00000000000017  -47.00000000000001  -3.9999999999999982       50.0  \
# ...

# %%
df = df.iloc[:, 1:]
df.head()
# Out:
#        09:40:50  26.0466  10.0252  14.4485  8.4499  16.1151    13.43   19.649  \
# 0  09:40:50.002  22.3896  11.2917  15.5731  8.2512  15.2678  14.7828  20.3893
# 1  09:40:50.004  16.6999  11.5905  15.6996  7.4461  14.1830  14.9755  20.5631
# 2  09:40:50.006   9.5022  11.6445  14.6918  6.2064  12.5756  14.4724  19.8746
# 3  09:40:50.008   2.1006  11.8186  12.9464  5.5676  10.6398  13.8879  18.5196
# 4  09:40:50.010  -4.0280  11.6355  11.1315  6.4536   9.0430  13.3979  16.9767
#
#    13.3862  19.3819  ...  0.0.12  0.0.13  -188.00000000000003       8411.0  \
# 0  14.9479  20.2633  ...     0.0     0.0          -172.349903  8414.343387
# 1  15.1158  19.7721  ...     0.0     0.0          -155.794864  8418.160738
# 2  14.2122  18.0098  ...     0.0     0.0          -140.564873  8424.106395
# 3  12.7470  15.8825  ...     0.0     0.0          -128.889922  8433.834701
# 4  11.0312  14.2353  ...     0.0     0.0          -123.000000  8449.000000
#
# ...

# %%
cols = ['Time-Stamps', 'FP1', 'FP2', 'F3', 'F4', 'C4', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'P7', 'P8', 'FZ', 'CZ', 'PZ', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6','ECG-1','ECG-2','ECG-3','ECG-4','ECG-5','accelerometer-x-l', 'accelerometer-y-l', 'accelerometer-z-l', 'Gyro-x-l', 'Gyro-y-l', 'Gyro-z-l', 'NC/SC-l', 'accelerometer-x-r', 'accelerometer-y-r', 'accelerometer-z-r', 'Gyro-x-r', 'Gyro-y-r', 'Gyro-z-r', 'NC/SC-r', 'accelerometer-x-w', 'accelerometer-y-w', 'accelerometer-z-w', 'Gyro-x-w', 'Gyro-y-w', 'Gyro-z-w', 'NC/SC-w', 'accelerometer-x-a', 'accelerometer-y-a', 'accelerometer-z-a', 'Gyro-x-a', 'Gyro-y-a', 'Gyro-z-a', 'NC/SC-a','FoG']
len(cols)
# Out:
# 60

# %%
col_drops = ['Time-Stamps', 'FP1', 'FP2', 'F3', 'F4', 'C4', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'P7', 'P8', 'FZ', 'CZ', 'PZ', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6','ECG-1','ECG-2','ECG-3','ECG-4','ECG-5', 'accelerometer-x-r', 'accelerometer-y-r', 'accelerometer-z-r', 'Gyro-x-r', 'Gyro-y-r', 'Gyro-z-r', 'NC/SC-r', 'accelerometer-x-w', 'accelerometer-y-w', 'accelerometer-z-w', 'Gyro-x-w', 'Gyro-y-w', 'Gyro-z-w', 'NC/SC-w', 'accelerometer-x-a', 'accelerometer-y-a', 'accelerometer-z-a', 'Gyro-x-a', 'Gyro-y-a', 'Gyro-z-a', 'NC/SC-a','FoG']
len(col_drops)
# Out:
# 53

# %%
df.columns = cols
df.head()
# Out:
#     Time-Stamps      FP1      FP2       F3      F4       C4       C4       P3  \
# 0  09:40:50.002  22.3896  11.2917  15.5731  8.2512  15.2678  14.7828  20.3893
# 1  09:40:50.004  16.6999  11.5905  15.6996  7.4461  14.1830  14.9755  20.5631
# 2  09:40:50.006   9.5022  11.6445  14.6918  6.2064  12.5756  14.4724  19.8746
# 3  09:40:50.008   2.1006  11.8186  12.9464  5.5676  10.6398  13.8879  18.5196
# 4  09:40:50.010  -4.0280  11.6355  11.1315  6.4536   9.0430  13.3979  16.9767
#
#         P4       O1  ...  Gyro-z-w  NC/SC-w  accelerometer-x-a  \
# 0  14.9479  20.2633  ...       0.0      0.0        -172.349903
# 1  15.1158  19.7721  ...       0.0      0.0        -155.794864
# 2  14.2122  18.0098  ...       0.0      0.0        -140.564873
# 3  12.7470  15.8825  ...       0.0      0.0        -128.889922
# 4  11.0312  14.2353  ...       0.0      0.0        -123.000000
#
#    accelerometer-y-a  accelerometer-z-a   Gyro-x-a   Gyro-y-a   Gyro-z-a  \
# ...

# %%
ans = df.loc[df['FoG']==1]
ans.loc[:, ['accelerometer-x-l', 'accelerometer-y-l', 'accelerometer-z-l',
       'Gyro-x-l', 'Gyro-y-l', 'Gyro-z-l', 'NC/SC-l']]
# Out:
#        accelerometer-x-l  accelerometer-y-l  accelerometer-z-l    Gyro-x-l  \
# 6999         7549.000000        -425.000000       -2811.000000  530.000000
# 7000         7564.796034        -643.873135       -2911.344273  599.460840
# 7001         7602.939033        -900.696804       -3022.668847  690.914421
# 7002         7654.284015       -1165.283906       -3137.421285  795.937581
# 7003         7709.685998       -1407.447339       -3248.049148  906.107161
# ...                  ...                ...                ...         ...
# 28494        7828.000000         349.000000       -3772.000000 -424.000000
# 28495        7818.046991         359.403661       -3766.458725 -426.039742
# 28496        7806.397785         364.881886       -3758.544019 -426.627097
# 28497        7794.425083         367.958281       -3747.399951 -424.594580
# 28498        7783.501588         371.156451       -3732.170589 -418.774709
#
#           Gyro-y-l     Gyro-z-l    NC/SC-l
# ...

# %%
y = df['FoG']
y.value_counts()
# Out:
# 1    17000
# 0    16000
# Name: FoG, dtype: int64

# %%
X = df.drop(col_drops, axis=1)
X.head()
# Out:
#    accelerometer-x-l  accelerometer-y-l  accelerometer-z-l    Gyro-x-l  \
# 0        8156.760184        1167.079522       -1874.872336 -100.504447
# 1        8158.562436        1171.968804       -1870.347855 -102.015170
# 2        8161.384597        1176.918325       -1867.287206 -103.473669
# 3        8164.204505        1181.178565       -1866.551038 -104.821446
# 4        8166.000000        1184.000000       -1869.000000 -106.000000
#
#     Gyro-y-l  Gyro-z-l    NC/SC-l
# 0 -10.361644 -9.834574  76.007012
# 1 -11.099880 -8.564859  76.020768
# 2 -12.057294 -7.277856  76.031018
# 3 -13.076472 -6.060569  76.027512
# 4 -14.000000 -5.000000  76.000000

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train.columns
# Out:
# Index(['accelerometer-x-l', 'accelerometer-y-l', 'accelerometer-z-l',
#        'Gyro-x-l', 'Gyro-y-l', 'Gyro-z-l', 'NC/SC-l'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Time-Stamps          0
# FP1                  0
# FP2                  0
# F3                   0
# F4                   0
# C4                   0
# C4                   0
# P3                   0
# P4                   0
# O1                   0
# O2                   0
# F7                   0
# F8                   0
# P7                   0
# P8                   0
# FZ                   0
# CZ                   0
# PZ                   0
# FC1                  0
# FC2                  0
# CP1                  0
# CP2                  0
# FC5                  0
# FC6                  0
# CP5                  0
# CP6                  0
# ECG-1                0
# ECG-2                0
# ECG-3                0
# ECG-4                0
# ECG-5                0
# accelerometer-x-l    0
# accelerometer-y-l    0
# accelerometer-z-l    0
# Gyro-x-l             0
# Gyro-y-l             0
# Gyro-z-l             0
# NC/SC-l              0
# accelerometer-x-r    0
# accelerometer-y-r    0
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

# %%
numerical_transformer = Pipeline(steps=[
    ('scale', StandardScaler()),
])

preprocess = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, X_train.columns)
    ]
)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators = 10)

# %%
my_pipeline = Pipeline(steps=[
    ('preprocess', preprocess),
    ('model', model)
])
my_pipeline
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scale',
#                                                                    StandardScaler())]),
#                                                   Index(['accelerometer-x-l', 'accelerometer-y-l', 'accelerometer-z-l',
#        'Gyro-x-l', 'Gyro-y-l', 'Gyro-z-l', 'NC/SC-l'],
#       dtype='object'))])),
#                 ('model', RandomForestClassifier(n_estimators=10))])

# %%
my_pipeline.fit(X_train, y_train)

preds = my_pipeline.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      3216
#            1       0.98      0.97      0.98      3384
#
#     accuracy                           0.98      6600
#    macro avg       0.98      0.98      0.98      6600
# weighted avg       0.98      0.98      0.98      6600

# %%
print(X_train.head(), X_test.head())
# Out:
#        accelerometer-x-l  accelerometer-y-l  accelerometer-z-l    Gyro-x-l  \
# 31119        8051.000000        1915.000000       -1553.000000 -135.000000
# 24474        7012.000000       -1267.000000       -4426.000000 -115.000000
# 5439         6538.000000         229.000000       -3992.000000  134.000000
# 31326        8076.561483        1820.880446       -1558.736547 -111.611364
# 24682        6990.754102       -1108.253076       -4460.158271 -131.272117
#
#          Gyro-y-l    Gyro-z-l    NC/SC-l
# 31119  -43.000000  -53.000000  77.000000
# 24474  -12.000000 -116.000000  77.000000
# 5439  -849.000000 -230.000000  77.000000
# 31326   -7.387917   10.753216  77.141521
# 24682   92.037997 -168.798966  76.378770          accelerometer-x-l  accelerometer-y-l  accelerometer-z-l    Gyro-x-l  \
# 29383        8091.261825        2028.410997       -1792.764424 -155.745357
# 21641        7103.606412       -1268.963469       -4011.985207 -111.522898
# ...

# %%
import joblib

# %%
ref_cols = X_train.columns
target = 'FoG'

# %%
joblib.dump([my_pipeline, ref_cols, target], filename='model2.pkl')
# Out:
# ['model2.pkl']

# %%
X_test
# Out:
#        accelerometer-x-l  accelerometer-y-l  accelerometer-z-l     Gyro-x-l  \
# 29383        8091.261825        2028.410997       -1792.764424  -155.745357
# 21641        7103.606412       -1268.963469       -4011.985207  -111.522898
# 30422        8147.657863        1815.600933       -1615.376031  -109.880146
# 1435         8172.547654         -14.319205       -1720.203409   113.606023
# 20073        7001.248612        -483.895246       -3679.257514  -224.638132
# ...                  ...                ...                ...          ...
# 29937        8313.790962        1771.919597       -1536.359364   -62.669221
# 3562         4872.863308         341.170845          46.498252 -1646.439745
# 5001         8168.528514       -1018.089521       -3225.051465  -205.034683
# 10624        8206.000000        -874.000000       -3033.000000   172.000000
# 19471        7574.185199        -763.013698       -4199.399472   -76.670220
#
#          Gyro-y-l    Gyro-z-l    NC/SC-l
# ...
